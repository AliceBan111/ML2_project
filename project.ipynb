# %% [markdown]
# # Project Description

# %% [markdown]
# # Part 1: Data Preparation

# %%
import pandas as pd

df = pd.read_csv('KAG_energydata_complete.csv', index_col=0)
print(df.shape)
print(df.columns)
print(df.head(10))
df.info()
# Out:
# (19735, 28)
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4',
#        'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9',
#        'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')
#                      Appliances  lights         T1       RH_1     T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#                           RH_2     T3       RH_3         T4       RH_4  ...  \
# date                                                                    ...
# 2016-01-11 17:00:00  44.790000  19.79  44.730000  19.000000  45.566667  ...
# 2016-01-11 17:10:00  44.722500  19.79  44.790000  19.000000  45.992500  ...
# 2016-01-11 17:20:00  44.626667  19.79  44.933333  18.926667  45.890000  ...
# 2016-01-11 17:30:00  44.590000  19.79  45.000000  18.890000  45.723333  ...
# 2016-01-11 17:40:00  44.530000  19.79  45.000000  18.890000  45.530000  ...
# 2016-01-11 17:50:00  44.500000  19.79  44.933333  18.890000  45.730000  ...
# 2016-01-11 18:00:00  44.500000  19.79  44.900000  18.890000  45.790000  ...
# 2016-01-11 18:10:00  44.500000  19.73  44.900000  18.890000  45.863333  ...
# 2016-01-11 18:20:00  44.433333  19.73  44.790000  18.890000  45.790000  ...
# 2016-01-11 18:30:00  44.400000  19.79  44.863333  18.890000  46.096667  ...
#
#                             T9   RH_9     T_out  Press_mm_hg     RH_out  \
# date
# 2016-01-11 17:00:00  17.033333  45.53  6.600000   733.500000  92.000000
# 2016-01-11 17:10:00  17.066667  45.56  6.483333   733.600000  92.000000
# 2016-01-11 17:20:00  17.000000  45.50  6.366667   733.700000  92.000000
# 2016-01-11 17:30:00  17.000000  45.40  6.250000   733.800000  92.000000
# 2016-01-11 17:40:00  17.000000  45.40  6.133333   733.900000  92.000000
# 2016-01-11 17:50:00  17.000000  45.29  6.016667   734.000000  92.000000
# 2016-01-11 18:00:00  17.000000  45.29  5.900000   734.100000  92.000000
# 2016-01-11 18:10:00  17.000000  45.29  5.916667   734.166667  91.833333
# 2016-01-11 18:20:00  17.000000  45.29  5.933333   734.233333  91.666667
# 2016-01-11 18:30:00  17.000000  45.29  5.950000   734.300000  91.500000
#
#                      Windspeed  Visibility  Tdewpoint        rv1        rv2
# date
# 2016-01-11 17:00:00   7.000000   63.000000   5.300000  13.275433  13.275433
# 2016-01-11 17:10:00   6.666667   59.166667   5.200000  18.606195  18.606195
# 2016-01-11 17:20:00   6.333333   55.333333   5.100000  28.642668  28.642668
# 2016-01-11 17:30:00   6.000000   51.500000   5.000000  45.410389  45.410389
# 2016-01-11 17:40:00   5.666667   47.666667   4.900000  10.084097  10.084097
# 2016-01-11 17:50:00   5.333333   43.833333   4.800000  44.919484  44.919484
# 2016-01-11 18:00:00   5.000000   40.000000   4.700000  47.233763  47.233763
# 2016-01-11 18:10:00   5.166667   40.000000   4.683333  33.039890  33.039890
# 2016-01-11 18:20:00   5.333333   40.000000   4.666667  31.455702  31.455702
# 2016-01-11 18:30:00   5.500000   40.000000   4.650000   3.089314   3.089314
#
# [10 rows x 28 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 19735 entries, 2016-01-11 17:00:00 to 2016-05-27 18:00:00
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Appliances   19735 non-null  int64
#  1   lights       19735 non-null  int64
#  2   T1           19735 non-null  float64
#  3   RH_1         19735 non-null  float64
#  4   T2           19735 non-null  float64
#  5   RH_2         19735 non-null  float64
#  6   T3           19735 non-null  float64
#  7   RH_3         19735 non-null  float64
#  8   T4           19735 non-null  float64
#  9   RH_4         19735 non-null  float64
#  10  T5           19735 non-null  float64
#  11  RH_5         19735 non-null  float64
#  12  T6           19735 non-null  float64
#  13  RH_6         19735 non-null  float64
#  14  T7           19735 non-null  float64
#  15  RH_7         19735 non-null  float64
#  16  T8           19735 non-null  float64
#  17  RH_8         19735 non-null  float64
#  18  T9           19735 non-null  float64
#  19  RH_9         19735 non-null  float64
#  20  T_out        19735 non-null  float64
#  21  Press_mm_hg  19735 non-null  float64
#  22  RH_out       19735 non-null  float64
#  23  Windspeed    19735 non-null  float64
#  24  Visibility   19735 non-null  float64
#  25  Tdewpoint    19735 non-null  float64
#  26  rv1          19735 non-null  float64
#  27  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2)
# memory usage: 4.4+ MB

# %% [markdown]
# # Part 2: Feature Engineering

# %% [markdown]
# ## 1. Time features

# %%
import numpy as np

# %%
df = df.copy()
df.index = pd.to_datetime(df.index)

# %%
# extract basic time features
df['hour'] = df.index.hour
df['day_of_week'] = df.index.dayofweek  
df['month'] = df.index.month
df['day_of_month'] = df.index.day
df['day_of_year'] = df.index.dayofyear

# %%
# weekend or not
df['is_weekend'] = (df.index.dayofweek >= 5).astype(int)

# %%
conditions = [
    (df['hour'] >= 6) & (df['hour'] < 12),
    (df['hour'] >= 12) & (df['hour'] < 18),
    (df['hour'] >= 18) & (df['hour'] < 24)
]

choices = [0, 1, 2]  # morning, afternoon, evening

df['time_period'] = np.select(conditions, choices, default=3) # night

# %%
# to encode periodic time features

"""
In order to capture periodic patterns, we apply cyclical encoding using sine and cosine transformations. 
This converts discrete time units into continuous circular coordinates.
It maintains the proximity between adjacent periods and eliminating artificial discontinuities at period boundaries.

"""

# hour
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

# week
df['day_of_week_sin'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
df['day_of_week_cos'] = np.cos(2 * np.pi * df['day_of_week'] / 7)

# month
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

# day of month
df['day_of_month_sin'] = np.sin(2 * np.pi * df['day_of_month'] / 30)
df['day_of_month_cos'] = np.cos(2 * np.pi * df['day_of_month'] / 30)

# day of year
df['day_of_year_sin'] = np.sin(2 * np.pi * df['day_of_year'] / 366)
df['day_of_year_cos'] = np.cos(2 * np.pi * df['day_of_year'] / 366)

# %% [markdown]
# ## 2. Temperature features

# %%
df["T_indoor_avg"] = df[df.filter(like='T').columns.drop('T6')].mean(axis=1) # average temperature of 8 rooms
df["T_indoor_std"] = df[df.filter(like='T').columns.drop('T6')].std(axis=1) # standard error of temperature of 8 rooms
df["T_indoor_max"] = df[df.filter(like='T').columns.drop('T6')].max(axis=1) # maximum temperature of 8 rooms
df["T_indoor_min"] = df[df.filter(like='T').columns.drop('T6')].min(axis=1) # minimum temperature of 8 rooms
df["T_indoor_range"] = df["T_indoor_max"] - df["T_indoor_min"] # the range of indoor temperature
df['T_indoor_change'] = df['T_indoor_avg'].diff() # change rate of indoor temperature

# %%
# the difference between indoor and outdoor temperatures
df["T_diff_1"] = df["T_indoor_avg"] - df["T6"]
df["T_diff_2"] = df["T_indoor_avg"] - df["T_out"]

# %% [markdown]
# ## 3. Humidity features

# %%
df["RH_indoor_avg"] = df[df.filter(like='RH').columns.drop('RH_6')].mean(axis=1) # average humidity of 8 rooms
df["RH_indoor_std"] = df[df.filter(like='RH').columns.drop('RH_6')].std(axis=1) # standard error of humidity of 8 rooms
df["RH_indoor_max"] = df[df.filter(like='RH').columns.drop('RH_6')].max(axis=1) # maximum humidity of 8 rooms
df["RH_indoor_min"] = df[df.filter(like='RH').columns.drop('RH_6')].min(axis=1) # minimum humidity of 8 rooms
df["RH_indoor_range"] = df["RH_indoor_max"] - df["RH_indoor_min"] # the range of indoor humidity
df['RH_indoor_change'] = df['RH_indoor_avg'].diff() # change rate of indoor humidity

# %%
# the difference between indoor and outdoor humidity
df["RH_diff_1"] = df["RH_indoor_avg"] - df["RH_6"]
df["RH_diff_2"] = df["RH_indoor_avg"] - df["RH_out"]

# %%
pip install metpy

# %%
# comfort measures
import metpy.calc as mpcalc
from metpy.calc import heat_index
from metpy.units import units
temp = df["T_indoor_avg"].values * units.degC
humidity = df["RH_indoor_avg"].values * units.percent

# heat index
df["heat_index"] = heat_index(temp, humidity)

# dewpoint
df["dewpoint"] = mpcalc.dewpoint_from_relative_humidity(temp, humidity)

# %% [markdown]
# ## 4. Weather measures

# %%
# weather comprehensive measure
df["weather_com"] = df["T_out"].values * df["RH_out"].values *0.01 * df["Windspeed"].values

# %%
# change rate
df['T_out_change'] = df['T_out'].diff()
df['Press_change'] = df['Press_mm_hg'].diff()
df['Windspeed_change'] = df['Windspeed'].diff()

# %% [markdown]
# ## 5. Lag features

# %%
# appliance lag
target_col='Appliances'
df[f'{target_col}_lag1'] = df[target_col].shift(1)  
df[f'{target_col}_lag2'] = df[target_col].shift(2)  
df[f'{target_col}_lag3'] = df[target_col].shift(3)
df[f'{target_col}_lag6'] = df[target_col].shift(6)
df[f'{target_col}_lag144'] = df[target_col].shift(144)

# %%
# lights lag
df['lights_lag1'] = df['lights'].shift(1)  
df['lights_lag2'] = df['lights'].shift(2)  
df['lights_lag3'] = df['lights'].shift(3)
df['lights_lag4'] = df['lights'].shift(6)
df['lights_lag5'] = df['lights'].shift(144)

# %%
# weather lag
df['T_indoor_lag1'] = df['T_indoor_avg'].shift(1)
df['T_indoor_lag6'] = df['T_indoor_avg'].shift(6)

df['T_out_lag1'] = df['T_out'].shift(1)
df['T_out_lag6'] = df['T_out'].shift(6)

# %% [markdown]
# ## 6. Rolling features

# %%
# appliance rolling
df[f'{target_col}_rolling_mean_6'] = df[target_col].rolling(window=6, min_periods=1).mean()
df[f'{target_col}_rolling_mean_18'] = df[target_col].rolling(window=18, min_periods=1).mean()
df[f'{target_col}_rolling_max_6'] = df[target_col].rolling(window=6, min_periods=1).max()
df[f'{target_col}_rolling_min_6'] = df[target_col].rolling(window=6, min_periods=1).min()
df[f'{target_col}_rolling_std_18'] = df[target_col].rolling(window=18, min_periods=1).std()
df[f'{target_col}_rolling_std_36'] = df[target_col].rolling(window=36, min_periods=1).std()
df[f'{target_col}_MA_3'] = df[target_col].rolling(window=3, min_periods=1).mean()
df[f'{target_col}_MA_12'] = df[target_col].rolling(window=12, min_periods=1).mean()

# %%
# lights rolling
df['lights_rolling_mean_6'] = df['lights'].rolling(window=6, min_periods=1).mean()
df['lights_rolling_mean_18'] = df['lights'].rolling(window=18, min_periods=1).mean()
df['lights_rolling_max_6'] = df['lights'].rolling(window=6, min_periods=1).max()
df['lights_rolling_min_6'] = df['lights'].rolling(window=6, min_periods=1).min()
df['lights_rolling_std_18'] = df['lights'].rolling(window=18, min_periods=1).std()
df['lights_rolling_std_36'] = df['lights'].rolling(window=36, min_periods=1).std()
df['lights_MA_3'] = df['lights'].rolling(window=3, min_periods=1).mean()
df['lights_MA_12'] = df['lights'].rolling(window=12, min_periods=1).mean()

# %%
# weather rolling
df['T_indoor_rolling_mean_6'] = df['T_indoor_avg'].rolling(window=6, min_periods=1).mean()
df['T_indoor_rolling_max_6'] = df['T_indoor_avg'].rolling(window=6, min_periods=1).max()
df['T_indoor_rolling_min_6'] = df['T_indoor_avg'].rolling(window=6, min_periods=1).min()
df['T_indoor_rolling_std_6'] = df['T_indoor_avg'].rolling(window=6, min_periods=1).std()

df['T_out_rolling_mean_6'] = df['T_out'].rolling(window=6, min_periods=1).mean()
df['T_out_rolling_std_6'] = df['T_out'].rolling(window=6, min_periods=1).std()

# %% [markdown]
# # Part 3: Feature Selection

# %%
# split train and test dataset
from sklearn.model_selection import train_test_split

X = df.drop(columns=["Appliances"]) 
y = df["Appliances"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
train_df = X_train.copy()
train_df["Appliances"] = y_train

# %%
# correlation-based feature selection
corr_matrix = train_df.corr()
corr_with_target = corr_matrix[target_col].drop(target_col, errors='ignore')

k = 60
top_k = corr_with_target.abs().sort_values(ascending=False)[:k].index
selected_features = train_df[top_k]

selected_corr_matrix = selected_features.corr()
selected_corr_matrix
# Out:
#                             Appliances_MA_3  Appliances_rolling_max_6  \
# Appliances_MA_3                    1.000000                  0.866869
# Appliances_rolling_max_6           0.866869                  1.000000
# Appliances_lag1                    0.942909                  0.780862
# Appliances_rolling_mean_6          0.895254                  0.936022
# Appliances_MA_12                   0.761293                  0.820499
# Appliances_rolling_std_18          0.700599                  0.784429
# Appliances_rolling_mean_18         0.697297                  0.745632
# Appliances_rolling_min_6           0.660553                  0.632299
# Appliances_lag2                    0.861566                  0.769887
# Appliances_rolling_std_36          0.546153                  0.600409
# Appliances_lag3                    0.651211                  0.751734
# Appliances_lag6                    0.398527                  0.534762
# hour_sin                          -0.287110                 -0.284807
# hour                               0.266104                  0.278622
# hour_cos                          -0.240080                 -0.267464
# lights_MA_3                        0.255415                  0.249805
# lights_rolling_max_6               0.264507                  0.278892
# lights                             0.234243                  0.229471
# T_indoor_change                    0.271127                  0.256328
# Appliances_lag144                  0.232703                  0.244340
# lights_lag1                        0.237598                  0.231397
# lights_rolling_mean_6              0.247038                  0.254816
# lights_lag2                        0.233121                  0.228720
# lights_rolling_std_18              0.214748                  0.235044
# lights_lag3                        0.217483                  0.224670
# lights_MA_12                       0.211188                  0.227627
# time_period                       -0.176488                 -0.205313
# RH_diff_2                          0.184162                  0.185012
# T2                                 0.186564                  0.184750
# RH_out                            -0.174539                 -0.173068
# RH_indoor_max                     -0.172522                 -0.171290
# RH_indoor_range                   -0.171218                 -0.168098
# lights_rolling_mean_18             0.176004                  0.189108
# RH_indoor_min                     -0.159667                 -0.163559
# RH_indoor_std                     -0.159667                 -0.163559
# lights_lag5                        0.149729                  0.166075
# lights_lag4                        0.156362                  0.188169
# T_indoor_max                       0.159374                  0.142264
# lights_rolling_min_6               0.147766                  0.148487
# T_indoor_rolling_std_6             0.159276                  0.165357
# T6                                 0.138057                  0.128973
# T3                                 0.156739                  0.149344
# T_diff_1                          -0.132052                 -0.128040
# RH_8                              -0.130602                 -0.137158
# T_out                              0.122296                  0.111595
# T_out_lag1                         0.121784                  0.110476
# T_out_rolling_mean_6               0.120395                  0.108323
# T_out_lag6                         0.115934                  0.102099
# T_diff_2                          -0.110441                 -0.105134
# T_indoor_avg                       0.113179                  0.094189
# RH_1                               0.147234                  0.191389
# heat_index                         0.108240                  0.089654
# T_indoor_lag1                      0.106647                  0.088005
# T_indoor_rolling_max_6             0.104496                  0.084699
# lights_rolling_std_36              0.109542                  0.115540
# Press_change                       0.098754                  0.104245
# T1                                 0.109362                  0.097706
# T_indoor_rolling_mean_6            0.098878                  0.079242
# RH_6                              -0.091874                 -0.071094
# T_indoor_rolling_min_6             0.094492                  0.074369
#
#                             Appliances_lag1  Appliances_rolling_mean_6  \
# Appliances_MA_3                    0.942909                   0.895254
# Appliances_rolling_max_6           0.780862                   0.936022
# Appliances_lag1                    1.000000                   0.813164
# Appliances_rolling_mean_6          0.813164                   1.000000
# Appliances_MA_12                   0.685739                   0.885943
# Appliances_rolling_std_18          0.631499                   0.785750
# Appliances_rolling_mean_18         0.626506                   0.816374
# Appliances_rolling_min_6           0.593608                   0.799767
# Appliances_lag2                    0.756969                   0.844897
# Appliances_rolling_std_36          0.491617                   0.629980
# Appliances_lag3                    0.540121                   0.844904
# Appliances_lag6                    0.354079                   0.586289
# hour_sin                          -0.255119                  -0.336706
# hour                               0.236565                   0.315148
# hour_cos                          -0.213268                  -0.245571
# lights_MA_3                        0.229696                   0.274973
# lights_rolling_max_6               0.236768                   0.300429
# lights                             0.207084                   0.249551
# T_indoor_change                    0.243571                   0.276067
# Appliances_lag144                  0.207684                   0.242493
# lights_lag1                        0.217692                   0.254242
# lights_rolling_mean_6              0.221451                   0.282840
# lights_lag2                        0.208891                   0.255161
# lights_rolling_std_18              0.191546                   0.254985
# lights_lag3                        0.195014                   0.252286
# lights_MA_12                       0.188532                   0.254284
# time_period                       -0.156871                  -0.175020
# RH_diff_2                          0.163757                   0.210938
# T2                                 0.165536                   0.227072
# RH_out                            -0.155192                  -0.197488
# RH_indoor_max                     -0.153099                  -0.194644
# RH_indoor_range                   -0.152102                  -0.193306
# lights_rolling_mean_18             0.156971                   0.217335
# RH_indoor_min                     -0.141269                  -0.179787
# RH_indoor_std                     -0.141269                  -0.179787
# lights_lag5                        0.132853                   0.173179
# lights_lag4                        0.134918                   0.208796
# T_indoor_max                       0.140538                   0.207283
# lights_rolling_min_6               0.131861                   0.174023
# T_indoor_rolling_std_6             0.141354                   0.198398
# T6                                 0.122835                   0.151494
# T3                                 0.137735                   0.206793
# T_diff_1                          -0.117608                  -0.139852
# RH_8                              -0.115888                  -0.153193
# T_out                              0.108784                   0.136405
# T_out_lag1                         0.108313                   0.136351
# T_out_rolling_mean_6               0.107069                   0.135471
# T_out_lag6                         0.103045                   0.131771
# T_diff_2                          -0.098363                  -0.118181
# T_indoor_avg                       0.100418                   0.136670
# RH_1                               0.130623                   0.188704
# heat_index                         0.096028                   0.131539
# T_indoor_lag1                      0.094564                   0.130018
# T_indoor_rolling_max_6             0.092732                   0.126745
# lights_rolling_std_36              0.097906                   0.138826
# Press_change                       0.088005                   0.109538
# T1                                 0.096705                   0.147120
# T_indoor_rolling_mean_6            0.087707                   0.120275
# RH_6                              -0.081533                  -0.105454
# T_indoor_rolling_min_6             0.083813                   0.114361
#
#                             Appliances_MA_12  Appliances_rolling_std_18  \
# Appliances_MA_3                     0.761293                   0.700599
# Appliances_rolling_max_6            0.820499                   0.784429
# Appliances_lag1                     0.685739                   0.631499
# Appliances_rolling_mean_6           0.885943                   0.785750
# Appliances_MA_12                    1.000000                   0.871678
# Appliances_rolling_std_18           0.871678                   1.000000
# Appliances_rolling_mean_18          0.945388                   0.898065
# Appliances_rolling_min_6            0.755562                   0.597318
# Appliances_lag2                     0.709360                   0.636227
# Appliances_rolling_std_36           0.736050                   0.810067
# Appliances_lag3                     0.723006                   0.633908
# Appliances_lag6                     0.742189                   0.612785
# hour_sin                           -0.409167                  -0.378997
# hour                                0.392748                   0.384132
# hour_cos                           -0.223246                  -0.223970
# lights_MA_3                         0.301911                   0.310260
# lights_rolling_max_6                0.330186                   0.336083
# lights                              0.275802                   0.279963
# T_indoor_change                     0.222404                   0.218705
# Appliances_lag144                   0.239773                   0.240301
# lights_lag1                         0.278410                   0.286512
# lights_rolling_mean_6               0.314931                   0.326570
# lights_lag2                         0.279104                   0.289533
# lights_rolling_std_18               0.304938                   0.328698
# lights_lag3                         0.277356                   0.289724
# lights_MA_12                        0.313010                   0.324774
# time_period                        -0.152955                  -0.175137
# RH_diff_2                           0.240984                   0.212081
# T2                                  0.290854                   0.254816
# RH_out                             -0.224866                  -0.192354
# RH_indoor_max                      -0.220002                  -0.186247
# RH_indoor_range                    -0.221389                  -0.187468
# lights_rolling_mean_18              0.282652                   0.300235
# RH_indoor_min                      -0.195517                  -0.165395
# RH_indoor_std                      -0.195517                  -0.165395
# lights_lag5                         0.201400                   0.227157
# lights_lag4                         0.258650                   0.270291
# T_indoor_max                        0.267980                   0.146698
# lights_rolling_min_6                0.204004                   0.217608
# T_indoor_rolling_std_6              0.198602                   0.199721
# T6                                  0.162781                   0.111073
# T3                                  0.264411                   0.155671
# T_diff_1                           -0.141083                  -0.110076
# RH_8                               -0.183481                  -0.161517
# T_out                               0.150806                   0.097565
# T_out_lag1                          0.151698                   0.097687
# T_out_rolling_mean_6                0.152160                   0.097170
# T_out_lag6                          0.151342                   0.094521
# T_diff_2                           -0.121821                  -0.092277
# T_indoor_avg                        0.169533                   0.081598
# RH_1                                0.188488                   0.196793
# heat_index                          0.163862                   0.077596
# T_indoor_lag1                       0.164168                   0.076341
# T_indoor_rolling_max_6              0.161195                   0.074463
# lights_rolling_std_36               0.187207                   0.216264
# Press_change                        0.114631                   0.114660
# T1                                  0.213528                   0.147377
# T_indoor_rolling_mean_6             0.155167                   0.068128
# RH_6                               -0.122883                  -0.047655
# T_indoor_rolling_min_6              0.148761                   0.061823
#
#                             Appliances_rolling_mean_18  \
# Appliances_MA_3                               0.697297
# Appliances_rolling_max_6                      0.745632
# Appliances_lag1                               0.626506
# Appliances_rolling_mean_6                     0.816374
# Appliances_MA_12                              0.945388
# Appliances_rolling_std_18                     0.898065
# Appliances_rolling_mean_18                    1.000000
# Appliances_rolling_min_6                      0.726553
# Appliances_lag2                               0.654203
# Appliances_rolling_std_36                     0.802135
# Appliances_lag3                               0.671037
# Appliances_lag6                               0.686649
# hour_sin                                     -0.457010
# hour                                          0.441835
# hour_cos                                     -0.176578
# lights_MA_3                                   0.311344
# lights_rolling_max_6                          0.337479
# lights                                        0.281941
# T_indoor_change                               0.178386
# Appliances_lag144                             0.215137
# lights_lag1                                   0.287210
# lights_rolling_mean_6                         0.329233
# lights_lag2                                   0.290213
# lights_rolling_std_18                         0.330214
# lights_lag3                                   0.290993
# lights_MA_12                                  0.338919
# time_period                                  -0.117059
# RH_diff_2                                     0.249512
# T2                                            0.333510
# RH_out                                       -0.232998
# RH_indoor_max                                -0.227404
# RH_indoor_range                              -0.231987
# lights_rolling_mean_18                        0.326186
# RH_indoor_min                                -0.193738
# RH_indoor_std                                -0.193738
# lights_lag5                                   0.206997
# lights_lag4                                   0.280335
# T_indoor_max                                  0.305872
# lights_rolling_min_6                          0.229432
# T_indoor_rolling_std_6                        0.198973
# T6                                            0.161581
# T3                                            0.296382
# T_diff_1                                     -0.130959
# RH_8                                         -0.200072
# T_out                                         0.152797
# T_out_lag1                                    0.154913
# T_out_rolling_mean_6                          0.157137
# T_out_lag6                                    0.160130
# T_diff_2                                     -0.114351
# T_indoor_avg                                  0.190710
# RH_1                                          0.172618
# heat_index                                    0.184839
# T_indoor_lag1                                 0.186401
# T_indoor_rolling_max_6                        0.184974
# lights_rolling_std_36                         0.227281
# Press_change                                  0.115765
# T1                                            0.268272
# T_indoor_rolling_mean_6                       0.178978
# RH_6                                         -0.132036
# T_indoor_rolling_min_6                        0.172549
#
#                             Appliances_rolling_min_6  Appliances_lag2  \
# Appliances_MA_3                             0.660553         0.861566
# Appliances_rolling_max_6                    0.632299         0.769887
# Appliances_lag1                             0.593608         0.756969
# Appliances_rolling_mean_6                   0.799767         0.844897
# Appliances_MA_12                            0.755562         0.709360
# Appliances_rolling_std_18                   0.597318         0.636227
# Appliances_rolling_mean_18                  0.726553         0.654203
# Appliances_rolling_min_6                    1.000000         0.621034
# Appliances_lag2                             0.621034         1.000000
# Appliances_rolling_std_36                   0.518921         0.504669
# Appliances_lag3                             0.652468         0.756968
# Appliances_lag6                             0.578639         0.388592
# hour_sin                                   -0.386285        -0.264517
# hour                                        0.348457         0.246989
# hour_cos                                   -0.159085        -0.201243
# lights_MA_3                                 0.271034         0.226603
# lights_rolling_max_6                        0.289205         0.244016
# lights                                      0.251613         0.200203
# T_indoor_change                             0.216549         0.261821
# Appliances_lag144                           0.216785         0.199408
# lights_lag1                                 0.251004         0.207078
# lights_rolling_mean_6                       0.277871         0.230254
# lights_lag2                                 0.245206         0.217686
# lights_rolling_std_18                       0.251813         0.201679
# lights_lag3                                 0.243620         0.208885
# lights_MA_12                                0.259168         0.199878
# time_period                                -0.092726        -0.144468
# RH_diff_2                                   0.215032         0.168424
# T2                                          0.281150         0.175611
# RH_out                                     -0.207421        -0.156856
# RH_indoor_max                              -0.202053        -0.154292
# RH_indoor_range                            -0.206411        -0.153383
# lights_rolling_mean_18                      0.232457         0.169414
# RH_indoor_min                              -0.171381        -0.142117
# RH_indoor_std                              -0.171381        -0.142117
# lights_lag5                                 0.155927         0.136318
# lights_lag4                                 0.213649         0.154781
# T_indoor_max                                0.303875         0.157863
# lights_rolling_min_6                        0.184663         0.136549
# T_indoor_rolling_std_6                      0.186653         0.158566
# T6                                          0.181820         0.121594
# T3                                          0.279601         0.157357
# T_diff_1                                   -0.144912        -0.113460
# RH_8                                       -0.173648        -0.120352
# T_out                                       0.173802         0.108981
# T_out_lag1                                  0.175617         0.108783
# T_out_rolling_mean_6                        0.177313         0.107844
# T_out_lag6                                  0.179303         0.104341
# T_diff_2                                   -0.128288        -0.095614
# T_indoor_avg                                0.220646         0.106713
# RH_1                                        0.123510         0.168177
# heat_index                                  0.214342         0.102783
# T_indoor_lag1                               0.215442         0.100420
# T_indoor_rolling_max_6                      0.212630         0.098329
# lights_rolling_std_36                       0.158045         0.107333
# Press_change                                0.096973         0.090438
# T1                                          0.242132         0.110300
# T_indoor_rolling_mean_6                     0.206834         0.092757
# RH_6                                       -0.170823        -0.083245
# T_indoor_rolling_min_6                      0.201156         0.088363
#
#                             Appliances_rolling_std_36  ...      RH_1  \
# Appliances_MA_3                              0.546153  ...  0.147234
# Appliances_rolling_max_6                     0.600409  ...  0.191389
# Appliances_lag1                              0.491617  ...  0.130623
# Appliances_rolling_mean_6                    0.629980  ...  0.188704
# Appliances_MA_12                             0.736050  ...  0.188488
# Appliances_rolling_std_18                    0.810067  ...  0.196793
# Appliances_rolling_mean_18                   0.802135  ...  0.172618
# Appliances_rolling_min_6                     0.518921  ...  0.123510
# Appliances_lag2                              0.504669  ...  0.168177
# Appliances_rolling_std_36                    1.000000  ...  0.146370
# Appliances_lag3                              0.512199  ...  0.178087
# Appliances_lag6                              0.525103  ...  0.145258
# hour_sin                                    -0.476992  ... -0.033710
# hour                                         0.435463  ...  0.042670
# hour_cos                                    -0.029576  ... -0.044225
# lights_MA_3                                  0.289464  ...  0.169207
# lights_rolling_max_6                         0.323985  ...  0.170043
# lights                                       0.257377  ...  0.154419
# T_indoor_change                              0.082836  ...  0.037148
# Appliances_lag144                            0.176888  ...  0.047126
# lights_lag1                                  0.266709  ...  0.154823
# lights_rolling_mean_6                        0.315048  ...  0.181370
# lights_lag2                                  0.274603  ...  0.156503
# lights_rolling_std_18                        0.373702  ...  0.148849
# lights_lag3                                  0.280689  ...  0.158272
# lights_MA_12                                 0.347254  ...  0.191107
# time_period                                 -0.012883  ... -0.038492
# RH_diff_2                                    0.186685  ...  0.007875
# T2                                           0.327879  ...  0.271516
# RH_out                                      -0.168904  ...  0.243976
# RH_indoor_max                               -0.164342  ...  0.243893
# RH_indoor_range                             -0.170801  ...  0.336707
# lights_rolling_mean_18                       0.361138  ...  0.189983
# RH_indoor_min                               -0.131663  ... -0.025466
# RH_indoor_std                               -0.131663  ... -0.025466
# lights_lag5                                  0.242333  ...  0.098301
# lights_lag4                                  0.288897  ...  0.157934
# T_indoor_max                                 0.208767  ... -0.040543
# lights_rolling_min_6                         0.227653  ...  0.138147
# T_indoor_rolling_std_6                       0.192029  ... -0.089731
# T6                                           0.070442  ...  0.313726
# T3                                           0.197581  ...  0.099917
# T_diff_1                                    -0.048978  ... -0.318302
# RH_8                                        -0.153489  ...  0.694711
# T_out                                        0.066209  ...  0.361420
# T_out_lag1                                   0.069314  ...  0.362141
# T_out_rolling_mean_6                         0.073207  ...  0.363617
# T_out_lag6                                   0.081068  ...  0.365174
# T_diff_2                                    -0.039706  ... -0.384997
# T_indoor_avg                                 0.103174  ...  0.212211
# RH_1                                         0.146370  ...  1.000000
# heat_index                                   0.099817  ...  0.265115
# T_indoor_lag1                                0.101182  ...  0.211444
# T_indoor_rolling_max_6                       0.103447  ...  0.206882
# lights_rolling_std_36                        0.343897  ...  0.139711
# Press_change                                 0.103207  ...  0.072145
# T1                                           0.264231  ...  0.022490
# T_indoor_rolling_mean_6                      0.097435  ...  0.210028
# RH_6                                        -0.043760  ...  0.377829
# T_indoor_rolling_min_6                       0.091228  ...  0.213186
#
#                             heat_index  T_indoor_lag1  T_indoor_rolling_max_6  \
# Appliances_MA_3               0.108240       0.106647                0.104496
# Appliances_rolling_max_6      0.089654       0.088005                0.084699
# Appliances_lag1               0.096028       0.094564                0.092732
# Appliances_rolling_mean_6     0.131539       0.130018                0.126745
# Appliances_MA_12              0.163862       0.164168                0.161195
# Appliances_rolling_std_18     0.077596       0.076341                0.074463
# Appliances_rolling_mean_18    0.184839       0.186401                0.184974
# Appliances_rolling_min_6      0.214342       0.215442                0.212630
# Appliances_lag2               0.102783       0.100420                0.098329
# Appliances_rolling_std_36     0.099817       0.101182                0.103447
# Appliances_lag3               0.108636       0.106716                0.103796
# Appliances_lag6               0.120537       0.121021                0.117899
# hour_sin                     -0.219024      -0.238377               -0.239442
# hour                          0.165682       0.177790                0.177501
# hour_cos                     -0.006447      -0.010385                0.000765
# lights_MA_3                   0.025514       0.014334                0.014229
# lights_rolling_max_6          0.041303       0.031177                0.031335
# lights                        0.021127       0.011262                0.011169
# T_indoor_change               0.007056      -0.012673               -0.022714
# Appliances_lag144             0.083460       0.086177                0.083734
# lights_lag1                   0.023541       0.013141                0.013207
# lights_rolling_mean_6         0.030263       0.018354                0.018063
# lights_lag2                   0.026090       0.015275                0.015326
# lights_rolling_std_18         0.058228       0.049883                0.052074
# lights_lag3                   0.028338       0.017510                0.017330
# lights_MA_12                  0.035731       0.023196                0.023711
# time_period                   0.029877       0.031711                0.040590
# RH_diff_2                     0.370143       0.396902                0.393514
# T2                            0.714830       0.711550                0.710400
# RH_out                       -0.301446      -0.344921               -0.342562
# RH_indoor_max                -0.294740      -0.338712               -0.336147
# RH_indoor_range              -0.258036      -0.306035               -0.304521
# lights_rolling_mean_18        0.037705       0.024837                0.026081
# RH_indoor_min                -0.364261      -0.393392               -0.388280
# RH_indoor_std                -0.364261      -0.393392               -0.388280
# lights_lag5                  -0.006001      -0.010089               -0.009703
# lights_lag4                   0.031893       0.021892                0.021965
# T_indoor_max                  0.817773       0.832132                0.835539
# lights_rolling_min_6          0.026152       0.015793                0.015330
# T_indoor_rolling_std_6        0.034175       0.036215                0.056950
# T6                            0.787219       0.785955                0.777826
# T3                            0.839643       0.845763                0.847317
# T_diff_1                     -0.610263      -0.607819               -0.597726
# RH_8                          0.006356      -0.052432               -0.055325
# T_out                         0.809073       0.805399                0.798203
# T_out_lag1                    0.811320       0.808126                0.801417
# T_out_rolling_mean_6          0.814512       0.811801                0.805993
# T_out_lag6                    0.816293       0.814377                0.810656
# T_diff_2                     -0.611321      -0.605411               -0.596171
# T_indoor_avg                  0.997675       0.999711                0.998743
# RH_1                          0.265115       0.211444                0.206882
# heat_index                    1.000000       0.997490                0.996441
# T_indoor_lag1                 0.997490       1.000000                0.999273
# T_indoor_rolling_max_6        0.996441       0.999273                1.000000
# lights_rolling_std_36         0.029682       0.019847                0.024071
# Press_change                 -0.070718      -0.073762               -0.069116
# T1                            0.804309       0.812874                0.817100
# T_indoor_rolling_mean_6       0.996614       0.999469                0.999451
# RH_6                         -0.567208      -0.612848               -0.614107
# T_indoor_rolling_min_6        0.995871       0.998560                0.997928
#
#                             lights_rolling_std_36  Press_change        T1  \
# Appliances_MA_3                          0.109542      0.098754  0.109362
# Appliances_rolling_max_6                 0.115540      0.104245  0.097706
# Appliances_lag1                          0.097906      0.088005  0.096705
# Appliances_rolling_mean_6                0.138826      0.109538  0.147120
# Appliances_MA_12                         0.187207      0.114631  0.213528
# Appliances_rolling_std_18                0.216264      0.114660  0.147377
# Appliances_rolling_mean_18               0.227281      0.115765  0.268272
# Appliances_rolling_min_6                 0.158045      0.096973  0.242132
# Appliances_lag2                          0.107333      0.090438  0.110300
# Appliances_rolling_std_36                0.343897      0.103207  0.264231
# Appliances_lag3                          0.115777      0.089503  0.124146
# Appliances_lag6                          0.138096      0.081007  0.160187
# hour_sin                                -0.205930     -0.048761 -0.317178
# hour                                     0.148622      0.095691  0.237744
# hour_cos                                 0.224750      0.032266  0.216374
# lights_MA_3                              0.496591      0.174820  0.103118
# lights_rolling_max_6                     0.553990      0.165426  0.131345
# lights                                   0.436607      0.163198  0.090553
# T_indoor_change                         -0.050370     -0.058061 -0.111642
# Appliances_lag144                        0.074682      0.032939  0.092071
# lights_lag1                              0.458156      0.160946  0.095012
# lights_rolling_mean_6                    0.546758      0.176567  0.116136
# lights_lag2                              0.475322      0.157822  0.099566
# lights_rolling_std_18                    0.749212      0.128259  0.169908
# lights_lag3                              0.488470      0.152497  0.104233
# lights_MA_12                             0.617370      0.168926  0.137949
# time_period                              0.202833     -0.064999  0.204209
# RH_diff_2                               -0.085361     -0.140646  0.252634
# T2                                       0.182301     -0.049436  0.760372
# RH_out                                   0.121911      0.136358 -0.243090
# RH_indoor_max                            0.126673      0.134574 -0.236044
# RH_indoor_range                          0.117145      0.127772 -0.234806
# lights_rolling_mean_18                   0.670390      0.155193  0.153193
# RH_indoor_min                            0.139977      0.139898 -0.217004
# RH_indoor_std                            0.139977      0.139898 -0.217004
# lights_lag5                              0.195801      0.091598  0.097604
# lights_lag4                              0.511939      0.133823  0.116757
# T_indoor_max                             0.059605     -0.005656  0.859993
# lights_rolling_min_6                     0.413285      0.122818  0.093089
# T_indoor_rolling_std_6                   0.092983      0.078068  0.054727
# T6                                      -0.093710     -0.129988  0.411114
# T3                                      -0.022561     -0.036136  0.808126
# T_diff_1                                 0.128304      0.137058 -0.201554
# RH_8                                     0.070470     -0.024987 -0.139042
# T_out                                   -0.083068     -0.133899  0.435388
# T_out_lag1                              -0.079826     -0.128896  0.441897
# T_out_rolling_mean_6                    -0.075125     -0.122145  0.451751
# T_out_lag6                              -0.063707     -0.106465  0.471718
# T_diff_2                                 0.120803      0.144296 -0.197944
# T_indoor_avg                             0.018637     -0.075158  0.810210
# RH_1                                     0.139711      0.072145  0.022490
# heat_index                               0.029682     -0.070718  0.804309
# T_indoor_lag1                            0.019847     -0.073762  0.812874
# T_indoor_rolling_max_6                   0.024071     -0.069116  0.817100
# lights_rolling_std_36                    1.000000      0.076847  0.183660
# Press_change                             0.076847      1.000000 -0.016091
# T1                                       0.183660     -0.016091  1.000000
# T_indoor_rolling_mean_6                  0.021163     -0.071774  0.816334
# RH_6                                     0.162128      0.062731 -0.461716
# T_indoor_rolling_min_6                   0.018242     -0.074250  0.814866
#
#                             T_indoor_rolling_mean_6      RH_6  \
# Appliances_MA_3                            0.098878 -0.091874
# Appliances_rolling_max_6                   0.079242 -0.071094
# Appliances_lag1                            0.087707 -0.081533
# Appliances_rolling_mean_6                  0.120275 -0.105454
# Appliances_MA_12                           0.155167 -0.122883
# Appliances_rolling_std_18                  0.068128 -0.047655
# Appliances_rolling_mean_18                 0.178978 -0.132036
# Appliances_rolling_min_6                   0.206834 -0.170823
# Appliances_lag2                            0.092757 -0.083245
# Appliances_rolling_std_36                  0.097435 -0.043760
# Appliances_lag3                            0.098091 -0.084978
# Appliances_lag6                            0.113751 -0.088052
# hour_sin                                  -0.237860  0.252466
# hour                                       0.174716 -0.182316
# hour_cos                                   0.005257  0.147329
# lights_MA_3                                0.011134  0.130940
# lights_rolling_max_6                       0.027908  0.116744
# lights                                     0.008531  0.118495
# T_indoor_change                           -0.034573 -0.033224
# Appliances_lag144                          0.081064 -0.068305
# lights_lag1                                0.010331  0.120471
# lights_rolling_mean_6                      0.014814  0.140387
# lights_lag2                                0.012277  0.121873
# lights_rolling_std_18                      0.048074  0.102304
# lights_lag3                                0.014289  0.123001
# lights_MA_12                               0.020546  0.154981
# time_period                                0.044797  0.058588
# RH_diff_2                                  0.392023 -0.576114
# T2                                         0.707429 -0.332296
# RH_out                                    -0.340096  0.697363
# RH_indoor_max                             -0.333946  0.691045
# RH_indoor_range                           -0.301347  0.715735
# lights_rolling_mean_18                     0.023128  0.167532
# RH_indoor_min                             -0.388869  0.560171
# RH_indoor_std                             -0.388869  0.560171
# lights_lag5                               -0.011292  0.107130
# lights_lag4                                0.019587  0.125460
# T_indoor_max                               0.834132 -0.585492
# lights_rolling_min_6                       0.013218  0.134173
# T_indoor_rolling_std_6                     0.024770 -0.112790
# T6                                         0.779324 -0.536748
# T3                                         0.847087 -0.555876
# T_diff_1                                  -0.599693  0.443062
# RH_8                                      -0.049119  0.627786
# T_out                                      0.800216 -0.489688
# T_out_lag1                                 0.803638 -0.490543
# T_out_rolling_mean_6                       0.808455 -0.491032
# T_out_lag6                                 0.813595 -0.487878
# T_diff_2                                  -0.598925  0.365287
# T_indoor_avg                               0.998654 -0.613669
# RH_1                                       0.210028  0.377829
# heat_index                                 0.996614 -0.567208
# T_indoor_lag1                              0.999469 -0.612848
# T_indoor_rolling_max_6                     0.999451 -0.614107
# lights_rolling_std_36                      0.021163  0.162128
# Press_change                              -0.071774  0.062731
# T1                                         0.816334 -0.461716
# T_indoor_rolling_mean_6                    1.000000 -0.611263
# RH_6                                      -0.611263  1.000000
# T_indoor_rolling_min_6                     0.999459 -0.607624
#
#                             T_indoor_rolling_min_6
# Appliances_MA_3                           0.094492
# Appliances_rolling_max_6                  0.074369
# Appliances_lag1                           0.083813
# Appliances_rolling_mean_6                 0.114361
# Appliances_MA_12                          0.148761
# Appliances_rolling_std_18                 0.061823
# Appliances_rolling_mean_18                0.172549
# Appliances_rolling_min_6                  0.201156
# Appliances_lag2                           0.088363
# Appliances_rolling_std_36                 0.091228
# Appliances_lag3                           0.093087
# Appliances_lag6                           0.108031
# hour_sin                                 -0.235650
# hour                                      0.171658
# hour_cos                                  0.010010
# lights_MA_3                               0.008723
# lights_rolling_max_6                      0.024892
# lights                                    0.006557
# T_indoor_change                          -0.040688
# Appliances_lag144                         0.078398
# lights_lag1                               0.008114
# lights_rolling_mean_6                     0.011901
# lights_lag2                               0.009793
# lights_rolling_std_18                     0.044343
# lights_lag3                               0.011578
# lights_MA_12                              0.017470
# time_period                               0.048773
# RH_diff_2                                 0.389518
# T2                                        0.703099
# RH_out                                   -0.336554
# RH_indoor_max                            -0.330582
# RH_indoor_range                          -0.297162
# lights_rolling_mean_18                    0.020157
# RH_indoor_min                            -0.388001
# RH_indoor_std                            -0.388001
# lights_lag5                              -0.012539
# lights_lag4                               0.016620
# T_indoor_max                              0.831894
# lights_rolling_min_6                      0.011073
# T_indoor_rolling_std_6                   -0.007203
# T6                                        0.779756
# T3                                        0.846201
# T_diff_1                                 -0.600677
# RH_8                                     -0.042583
# T_out                                     0.801093
# T_out_lag1                                0.804636
# T_out_rolling_mean_6                      0.809703
# T_out_lag6                                0.815492
# T_diff_2                                 -0.600611
# T_indoor_avg                              0.997598
# RH_1                                      0.213186
# heat_index                                0.995871
# T_indoor_lag1                             0.998560
# T_indoor_rolling_max_6                    0.997928
# lights_rolling_std_36                     0.018242
# Press_change                             -0.074250
# T1                                        0.814866
# T_indoor_rolling_mean_6                   0.999459
# RH_6                                     -0.607624
# T_indoor_rolling_min_6                    1.000000
#
# [60 rows x 60 columns]

# %%
selected_target_corr = corr_with_target[top_k].sort_values(ascending=False)
for i, (feature, corr) in enumerate(selected_target_corr.items(), 1):
    sign = "+" if corr > 0 else "-"
    print(f"{i:2d}. {feature:35s}: {corr:7.4f} ({sign})")
# Out:
#  1. Appliances_MA_3                    :  0.8615 (+)
#  2. Appliances_rolling_max_6           :  0.7603 (+)
#  3. Appliances_lag1                    :  0.7568 (+)
#  4. Appliances_rolling_mean_6          :  0.7287 (+)
#  5. Appliances_MA_12                   :  0.6345 (+)
#  6. Appliances_rolling_std_18          :  0.6001 (+)
#  7. Appliances_rolling_mean_18         :  0.5783 (+)
#  8. Appliances_rolling_min_6           :  0.5464 (+)
#  9. Appliances_lag2                    :  0.5400 (+)
# 10. Appliances_rolling_std_36          :  0.4598 (+)
# 11. Appliances_lag3                    :  0.4391 (+)
# 12. Appliances_lag6                    :  0.3198 (+)
# 13. hour                               :  0.2260 (+)
# 14. lights_MA_3                        :  0.2251 (+)
# 15. lights_rolling_max_6               :  0.2246 (+)
# 16. lights                             :  0.2176 (+)
# 17. T_indoor_change                    :  0.2174 (+)
# 18. Appliances_lag144                  :  0.2137 (+)
# 19. lights_lag1                        :  0.2088 (+)
# 20. lights_rolling_mean_6              :  0.2074 (+)
# 21. lights_lag2                        :  0.1949 (+)
# 22. lights_rolling_std_18              :  0.1793 (+)
# 23. lights_lag3                        :  0.1759 (+)
# 24. lights_MA_12                       :  0.1752 (+)
# 25. RH_diff_2                          :  0.1588 (+)
# 26. T2                                 :  0.1562 (+)
# 27. lights_rolling_mean_18             :  0.1434 (+)
# 28. lights_lag5                        :  0.1303 (+)
# 29. lights_lag4                        :  0.1272 (+)
# 30. T_indoor_max                       :  0.1264 (+)
# 31. lights_rolling_min_6               :  0.1262 (+)
# 32. T_indoor_rolling_std_6             :  0.1247 (+)
# 33. T6                                 :  0.1236 (+)
# 34. T3                                 :  0.1227 (+)
# 35. T_out                              :  0.1083 (+)
# 36. T_out_lag1                         :  0.1076 (+)
# 37. T_out_rolling_mean_6               :  0.1061 (+)
# 38. T_out_lag6                         :  0.1017 (+)
# 39. T_indoor_avg                       :  0.0946 (+)
# 40. RH_1                               :  0.0939 (+)
# 41. heat_index                         :  0.0897 (+)
# 42. T_indoor_lag1                      :  0.0893 (+)
# 43. T_indoor_rolling_max_6             :  0.0875 (+)
# 44. lights_rolling_std_36              :  0.0868 (+)
# 45. Press_change                       :  0.0849 (+)
# 46. T1                                 :  0.0845 (+)
# 47. T_indoor_rolling_mean_6            :  0.0831 (+)
# 48. T_indoor_rolling_min_6             :  0.0797 (+)
# 49. RH_6                               : -0.0801 (-)
# 50. T_diff_2                           : -0.1005 (-)
# 51. RH_8                               : -0.1119 (-)
# 52. T_diff_1                           : -0.1210 (-)
# 53. RH_indoor_std                      : -0.1423 (-)
# 54. RH_indoor_min                      : -0.1423 (-)
# 55. RH_indoor_range                    : -0.1509 (-)
# 56. RH_indoor_max                      : -0.1525 (-)
# 57. RH_out                             : -0.1532 (-)
# 58. time_period                        : -0.1692 (-)
# 59. hour_cos                           : -0.2256 (-)
# 60. hour_sin                           : -0.2459 (-)

# %% [markdown]
# 1. The strong correlation between the target variable and its lagged and rolling statistics indicates autocorrelation, which is consistent with the persistent nature of residential appliance usage.
# 2. "Lights" feature is a behavorial proxy rather than a main driver as its correlation score is not high.

# %%
# Bottom correlation features
all_correlations = corr_with_target.abs().sort_values(ascending=False)
print(all_correlations.tail(20))
# Out:
# T_indoor_std       0.028703
# day_of_month       0.026763
# day_of_week        0.024823
# T_indoor_min       0.023654
# T9                 0.022225
# T_out_change       0.019856
# Tdewpoint          0.016903
# day_of_year_sin    0.013728
# day_of_year        0.013239
# dewpoint           0.012193
# day_of_year_cos    0.011220
# rv2                0.007158
# rv1                0.007158
# month_cos          0.007061
# month              0.006134
# Visibility         0.005451
# RH_4               0.004894
# is_weekend         0.002485
# RH_5               0.002350
# month_sin          0.001511
# Name: Appliances, dtype: float64
